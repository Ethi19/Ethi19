# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethi19/Ethi19/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0c31f19-6cbf-4f78-8a5a-7ec8daf3164a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0c31f19-6cbf-4f78-8a5a-7ec8daf3164a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving college_1.csv to college_1.csv

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-d04cea74-f19f-4c12-911d-5eddc62f6895" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d04cea74-f19f-4c12-911d-5eddc62f6895">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving college_2.csv to college_2.csv

# %%
df = pd.read_csv('college_1.csv')
df.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df1 = pd.read_csv('college_2.csv')
df1.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
dfs = [df, df1]
output = pd.concat(dfs)
output
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
des = df1[df1["CodeKata Score"] > 15000]
des.to_csv('Exceeded expectations.csv')
pd.read_csv('Exceeded expectations.csv')
# Out:
#    Unnamed: 0           Name  python  python_en  mysql  \
# 0           0  ASHOK KUMAR K     100          0     31
#
#    computational_thinking  Previous Geekions  CodeKata Score  \
# 0                       9              19400           19400
#
#                                Department  Rising
# 0  Electronics and Electrical Engineering       0

# %%
des = df1[df1 ["CodeKata Score"].between (10000, 15000, inclusive ='neither')]
des.to_csv('Exceeded expectations.csv')
pd.read_csv('Exceeded expectations.csv')
# Out:
#    Unnamed: 0               Name  python  python_en  mysql  \
# 0           1            Chandru       0         20      0
# 1           2  Ganesh Ramkumar R      -1         55     24
# 2           3    Bodipudi Harini      -1          0     35
#
#    computational_thinking  Previous Geekions  CodeKata Score  \
# 0                       0              14150           14490
# 1                       6               8790           10790
# 2                      -1              10040           10040
#
#                                   Department  Rising
# 0           Computer Science and Engineering     340
# 1           Computer Science and Engineering    2000
# 2  Electronics and Communication Engineering       0

# %%
des = df1[df1 ["CodeKata Score"].between (7000, 10000, inclusive ='neither')]
des.to_csv('Reached Expectation.csv')
pd.read_csv('Reached Expectation.csv')
# Out:
#     Unnamed: 0                    Name  python  python_en  mysql  \
# 0            4               VIINU V P      -1        100     24
# 1            5              Poojitha Y       0         78     35
# 2            6  Gowtham Chandrasekaran      -1          0      0
# 3            7               Gowtham R      -1         60      4
# 4            8                shifak N      58          0      0
# 5            9                 Balaji       -1        100     20
# 6           10                Rushitha      -1         15     62
# 7           11    Balaraman Muthupandi      -1          9      0
# 8           12                JPradhap     100          0      0
# 9           13           SRIRAMKUMAR B      -1          0      0
# 10          14               Praneetha      -1         23    100
# 11          15             Rahul Raj K      -1          0      0
# 12          16                 Guhan S      -1         72     35
# ...

# %%
des = df1[df1 ["CodeKata Score"] <6000]
des.to_csv('Unsatisfactory.csv')
pd.read_csv('Unsatisfactory.csv')
# Out:
#     Unnamed: 0               Name  python  python_en  mysql  \
# 0           22        santhoshini      -1         43      0
# 1           23         MUKESH S M      -1         46      0
# 2           24      P.GOVARDHANAN      -1         40      0
# 3           25       SHAIK DANISH      -1         43      0
# 4           26          sridhar.s      -1         52      0
# 5           27  Vimalesh Fernando      -1          0      0
# 6           28      M.Karthikeyan      -1          0      4
# 7           29          Abishak s      -1         55     35
# 8           30      praveen raj j      24         -1      0
# 9           31         AMARNATH D      -1         52     12
# 10          32               bala      32         49      0
# 11          33               XY Z      -1         20     -1
# 12          34          Hariharan      -1         -1     -1
#
#     computational_thinking  Previous Geekions  CodeKata Score  \
# ...

# %%
avg = np.mean(df1['Rising'])
avg
# Out:
# 708.2857142857143

# %%
series = output['Name']
series.count()
# Out:
# 119

# %%
avgpy = np.mean(output['python'])
avgpy
# Out:
# 54.35294117647059

# %%
avgmsql = np.mean(output['mysql'])
avgmsql
# Out:
# 23.5

# %%
avgcp = np.mean(output['computational_thinking'])
avgcp
# Out:
# 2.2

# %%
avgeg = np.mean(output['python_en'])
avgeg
# Out:
# 29.65714285714286

# %%
df1.nlargest(n=3,columns=['Rising'])
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 8            shifak N      58          0      0                       0
# 2   Ganesh Ramkumar R      -1         55     24                       6
# 18     Narasimhan Y L      -1         -1      0                       0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 8                5180            8320  Electronics and Electrical Engineering
# 2                8790           10790        Computer Science and Engineering
# 18               4800            6800        Computer Science and Engineering
#
#     Rising
# 8     3140
# 2     2000
# 18    2000

# %%
df.nlargest(n=3,columns=['Previous Geekions'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
output.groupby(['Department']).sum().plot(kind='pie',y='CodeKata Score')

# %%
plt.barh(output['Department'],output['CodeKata Score'])
plt.title('Department topper')
plt.ylabel('Department')
plt.xlabel('Score')
plt.show()
